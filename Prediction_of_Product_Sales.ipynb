# %% [markdown]
# <a href="https://colab.research.google.com/github/saedsader/Prediction-of-product-sales/blob/main/Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Prediction of Product Sales

# %% [markdown]
# Author:Saed Sader

# %% [markdown]
# ##Project Overviwe

# %% [markdown]
# ##Load and Inspect Data

# %% [markdown]
# ##Clean Data

# %% [markdown]
# ##Exploratory Data Analysis

# %% [markdown]
# ##Feature Inspection
